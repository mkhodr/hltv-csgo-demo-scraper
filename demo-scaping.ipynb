# %% [markdown]
# # CS:GO DEMOS DATA SCRAPING

# %%
from bs4 import BeautifulSoup
from selenium import webdriver  
from fake_useragent import UserAgent
import requests
import time

# Base HLTV url
base_url = 'https://www.hltv.org'

# %% [markdown]
# ### Setting up functions for parsing the response data from HLTV

# %%
# Returns a BeautifulSoup object of the given URL
# required reloading for updating the userAgent to avoid CloudFlare protection
def get_soup(url):
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    ua = UserAgent()
    userAgent = ua.random
    options.add_argument(f'user-agent={userAgent}')
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    driver_soup = BeautifulSoup(driver.page_source)
    driver.quit()
    return driver_soup



# Retrieves the mathpages links from the response from the filtering process
# and creates and appends to mathpage_list
def get_matchpage_links(soup):
    matchpage_list = []                                             # Create a empty list to store the matchpage links
    match_soup = soup.find_all("div", {"class": "result-con"})      # Soup containing all matches on the page
    for match in match_soup:                                        # Looping thru all mathches found and getting the matchpage links
        div = match.find('a')
        href = div['href']
        matchpage_list.append(href)                                 # Appending links to list
    pagination = soup.find("div", {"class": "pagination-component pagination-top"})
    pagination = int(pagination.span.text.strip().split(' ')[-1])   # Checking for pagination info to see if there are more results
    if pagination > 100:                                            # Looping thru remaining pages
        for i in range(100, pagination, 100):
            offset=i
            soup = get_soup(filtering_url)
            match_soup = soup.find_all("div", {"class": "result-con"})
            for match in match_soup:
                div = match.find('a')
                href = div['href']
                matchpage_list.append(href)
    return matchpage_list


## Get the download link from pages and saves the .dem file to the selected directory
def get_download(matchpage_link, sleep_time=30):
    soup = get_soup(matchpage_link)
    match_a = soup.find("a", {"class": "stream-box"})
    try:
        end_url = match_a['data-demo-link']
        download_url = base_url + end_url
        options = webdriver.ChromeOptions()
        ua = UserAgent()
        userAgent = ua.random
        options.add_argument(f'user-agent={userAgent}')
        options.add_argument('--headless=new')
        prefs= {"download.default_directory":"C:\Programming\csgo_demo\demos_rar"}
        options.add_experimental_option("prefs",prefs)
        driver = webdriver.Chrome(options=options)
        driver.get(download_url)
        print(f'downloading match {matchpage_link}')
        print(f'sleeping for {sleep_time} seconds waiting for download')
        time.sleep(sleep_time)
        print('finished sleeping')
        driver.quit()
    except:
        print('Demo url not found or cloudflare protection')

# %% [markdown]
# ### Setting up the filter settings and loading the data from the response

# %%
# Filter settings for matches
offset = 0
start_date = '2023-01-01'
end_date = '2023-05-30'
map_name = 'de_mirage'
min_star = 2
filtering_url = f'https://www.hltv.org/results?offset={offset}&startDate={start_date}&endDate={end_date}&stars={str(min_star)}&map={map_name}'

print(filtering_url)
soup = get_soup(filtering_url)
matchpage_list = get_matchpage_links(soup)

# %%
matchpage_list
len(matchpage_list)
# Out:
# ['/matches/2364477/liquid-vs-grayhound-iem-dallas-2023',
#  '/matches/2364474/mouz-vs-heroic-iem-dallas-2023',
#  '/matches/2364472/g2-vs-og-iem-dallas-2023',
#  '/matches/2364474/mouz-vs-heroic-iem-dallas-2023',
#  '/matches/2364472/g2-vs-og-iem-dallas-2023',
#  '/matches/2364437/into-the-breach-vs-big-cct-2023-online-finals-1',
#  '/matches/2364579/apeks-vs-monte-esl-challenger-league-season-45-europe',
#  '/matches/2364426/ninjas-in-pyjamas-vs-into-the-breach-cct-2023-online-finals-1',
#  '/matches/2364360/big-vs-ninjas-in-pyjamas-esl-challenger-katowice-2023-europe-closed-qualifier',
#  '/matches/2364291/vitality-vs-apeks-blasttv-paris-major-2023',
#  '/matches/2364286/heroic-vs-faze-blasttv-paris-major-2023',
#  '/matches/2363890/faze-vs-natus-vincere-blasttv-paris-major-2023',
#  '/matches/2363885/faze-vs-bad-news-eagles-blasttv-paris-major-2023',
#  '/matches/2363884/ence-vs-ninjas-in-pyjamas-blasttv-paris-major-2023',
#  '/matches/2363882/furia-vs-g2-blasttv-paris-major-2023',
#  '/matches/2363880/heroic-vs-liquid-blasttv-paris-major-2023',
#  '/matches/2363846/ninjas-in-pyjamas-vs-og-blasttv-paris-major-2023-challengers-stage',
#  '/matches/2363743/ninjas-in-pyjamas-vs-mouz-blasttv-paris-major-2023-challengers-stage',
#  '/matches/2363910/pain-vs-big-brazy-party-2023',
#  '/matches/2363564/heroic-vs-furia-iem-rio-2023',
#  '/matches/2363563/vitality-vs-big-iem-rio-2023',
#  '/matches/2363562/og-vs-vitality-iem-rio-2023',
#  '/matches/2363560/natus-vincere-vs-big-iem-rio-2023',
#  '/matches/2363557/fnatic-vs-og-iem-rio-2023',
#  '/matches/2363555/og-vs-cloud9-iem-rio-2023',
#  '/matches/2363553/faze-vs-furia-iem-rio-2023',
#  '/matches/2363547/ninjas-in-pyjamas-vs-natus-vincere-iem-rio-2023',
#  '/matches/2363538/faze-vs-cloud9-blasttv-paris-major-2023-challengers-europe-last-chance-qualifier',
#  '/matches/2363197/g2-vs-vitality-blasttv-paris-major-2023-europe-rmr-b',
#  '/matches/2363193/big-vs-vitality-blasttv-paris-major-2023-europe-rmr-b',
#  '/matches/2363184/astralis-vs-spirit-blasttv-paris-major-2023-europe-rmr-b',
#  '/matches/2363216/pain-vs-furia-blasttv-paris-major-2023-americas-rmr',
#  '/matches/2363211/liquid-vs-furia-blasttv-paris-major-2023-americas-rmr',
#  '/matches/2363156/virtuspro-vs-mouz-blasttv-paris-major-2023-europe-rmr-a',
#  '/matches/2363491/cloud9-vs-forze-betboom-playlist-urbanistic-2023',
#  '/matches/2363474/og-vs-cloud9-iem-dallas-2023-europe-closed-qualifier',
#  '/matches/2363472/astralis-vs-cloud9-iem-dallas-2023-europe-closed-qualifier',
#  '/matches/2363473/og-vs-fnatic-iem-dallas-2023-europe-closed-qualifier',
#  '/matches/2363323/cloud9-vs-big-blast-premier-spring-showdown-2023-europe',
#  '/matches/2363324/pain-vs-liquid-blast-premier-spring-showdown-2023-americas',
#  '/matches/2363463/ninjas-in-pyjamas-vs-og-iem-dallas-2023-europe-closed-qualifier',
#  '/matches/2363313/ninjas-in-pyjamas-vs-og-blast-premier-spring-showdown-2023-europe',
#  '/matches/2362245/cloud9-vs-faze-esl-pro-league-season-17',
#  '/matches/2362243/faze-vs-natus-vincere-esl-pro-league-season-17',
#  '/matches/2362241/cloud9-vs-mouz-esl-pro-league-season-17',
#  '/matches/2362235/outsiders-vs-natus-vincere-esl-pro-league-season-17',
#  '/matches/2362230/liquid-vs-astralis-esl-pro-league-season-17',
#  '/matches/2362228/astralis-vs-spirit-esl-pro-league-season-17',
#  '/matches/2362223/spirit-vs-liquid-esl-pro-league-season-17',
#  '/matches/2362055/spirit-vs-astralis-esl-pro-league-season-17',
#  '/matches/2362215/og-vs-ninjas-in-pyjamas-esl-pro-league-season-17',
#  '/matches/2362198/mouz-vs-furia-esl-pro-league-season-17',
#  '/matches/2362193/outsiders-vs-cloud9-esl-pro-league-season-17',
#  '/matches/2361912/spirit-vs-ence-cct-central-europe-malta-finals-1',
#  '/matches/2361345/heroic-vs-g2-iem-katowice-2023',
#  '/matches/2361344/heroic-vs-natus-vincere-iem-katowice-2023',
#  '/matches/2361341/liquid-vs-vitality-iem-katowice-2023',
#  '/matches/2361701/big-vs-sprout-iem-rio-2023-europe-closed-qualifier',
#  '/matches/2361700/bad-news-eagles-vs-ence-iem-rio-2023-europe-closed-qualifier',
#  '/matches/2361337/faze-vs-liquid-iem-katowice-2023',
#  '/matches/2361332/vitality-vs-fnatic-iem-katowice-2023',
#  '/matches/2361331/heroic-vs-og-iem-katowice-2023',
#  '/matches/2361328/big-vs-spirit-iem-katowice-2023',
#  '/matches/2361324/outsiders-vs-fnatic-iem-katowice-2023',
#  '/matches/2361322/og-vs-mouz-iem-katowice-2023',
#  '/matches/2361321/vitality-vs-ninjas-in-pyjamas-iem-katowice-2023',
#  '/matches/2361300/fnatic-vs-og-iem-katowice-2023-play-in',
#  '/matches/2361301/furia-vs-big-iem-katowice-2023-play-in',
#  '/matches/2361299/spirit-vs-ninjas-in-pyjamas-iem-katowice-2023-play-in',
#  '/matches/2361066/astralis-vs-ninjas-in-pyjamas-blast-premier-spring-groups-2023',
#  '/matches/2361062/faze-vs-og-blast-premier-spring-groups-2023',
#  '/matches/2361061/vitality-vs-heroic-blast-premier-spring-groups-2023',
#  '/matches/2361060/natus-vincere-vs-ninjas-in-pyjamas-blast-premier-spring-groups-2023',
#  '/matches/2361059/og-vs-liquid-blast-premier-spring-groups-2023',
#  '/matches/2361057/big-vs-ninjas-in-pyjamas-blast-premier-spring-groups-2023',
#  '/matches/2361054/faze-vs-og-blast-premier-spring-groups-2023',
#  '/matches/2361053/heroic-vs-astralis-blast-premier-spring-groups-2023',
#  '/matches/2361051/natus-vincere-vs-ninjas-in-pyjamas-blast-premier-spring-groups-2023',
#  '/matches/2361050/g2-vs-big-blast-premier-spring-groups-2023']

# %% [markdown]
# # Downloading selected demos

# %%
for match in matchpage_list[0:20]:
    match_url = base_url + match
    print(match_url)
    get_download(match_url)
# Out:
# https://www.hltv.org/matches/2364477/liquid-vs-grayhound-iem-dallas-2023
# downloading match https://www.hltv.org/matches/2364477/liquid-vs-grayhound-iem-dallas-2023
# sleeping for 30 seconds waiting for download
# finished sleeping
# https://www.hltv.org/matches/